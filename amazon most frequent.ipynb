# %%
import pandas as pd

# %%
df = pd.read_csv("./companies/Amazon.csv")
df.head()
# Out:
#                                         problem_link  \
# 0  https://leetcode.com/problems/minimum-average-...
# 1  https://leetcode.com/problems/minimum-rounds-t...
# 2  https://leetcode.com/problems/partition-array-...
# 3  https://leetcode.com/problems/minimum-sum-of-f...
# 4  https://leetcode.com/problems/rearrange-array-...
#
#                                         problem_name  num_occur
# 0                         Minimum Average Difference          1
# 1               Minimum Rounds to Complete All Tasks          1
# 2           Partition Array According to Given Pivot          1
# 3  Minimum Sum of Four Digit Number After Splitti...          1
# 4                   Rearrange Array Elements by Sign          1

# %%
test = df.sort_values(['num_occur'], ascending=[False])
test.head(20)
# Out:
#                                           problem_link  \
# 591             https://leetcode.com/problems/two-sum/
# 465           https://leetcode.com/problems/lru-cache/
# 438   https://leetcode.com/problems/number-of-islands/
# 539     https://leetcode.com/problems/merge-intervals/
# 109  https://leetcode.com/problems/search-suggestio...
# 487  https://leetcode.com/problems/best-time-to-buy...
# 545      https://leetcode.com/problems/group-anagrams/
# 120  https://leetcode.com/problems/analyze-user-web...
# 589  https://leetcode.com/problems/longest-substrin...
# 163  https://leetcode.com/problems/k-closest-points...
# 399    https://leetcode.com/problems/meeting-rooms-ii/
# 569  https://leetcode.com/problems/merge-k-sorted-l...
# 552  https://leetcode.com/problems/trapping-rain-wa...
# 577                https://leetcode.com/problems/3sum/
# 572   https://leetcode.com/problems/valid-parentheses/
# 481         https://leetcode.com/problems/word-ladder/
# ...
